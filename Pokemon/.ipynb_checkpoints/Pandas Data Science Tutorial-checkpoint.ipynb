# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv",encoding="unicode_escape")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df[df.isnull()]
# Out:
#       # Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0   NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 1   NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 2   NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 3   NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 4   NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# ..   ..  ...    ...    ...  ..     ...      ...      ...      ...    ...
# 795 NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 796 NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 797 NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 798 NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
# 799 NaN  NaN    NaN    NaN NaN     NaN      NaN      NaN      NaN    NaN
#
#      Generation Legendary
# 0           NaN       NaN
# 1           NaN       NaN
# ...

# %%
df[df.notnull()]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.columns)

print(df[["Name"]].head(3))
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#         Name
# 0  Bulbasaur
# 1    Ivysaur
# 2   Venusaur

# %%
df.Name.tail(3)
# Out:
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, dtype: object

# %%
df[["Name"]].tail(3)
# Out:
#                     Name
# 797  HoopaHoopa Confined
# 798   HoopaHoopa Unbound
# 799            Volcanion

# %%
#specific location

df.iloc[2,1] # default index
# Out:
# 'Venusaur'

# %%
df[df["Type 1"] == "Fire"].head(3)
# Out:
#    #        Name Type 1  Type 2  HP Attack Defense Sp. Atk Sp. Def Speed  \
# 4  4  Charmander   Fire     NaN  39     52      43      60      50    65
# 5  5  Charmeleon   Fire     NaN  58     64      58      80      65    80
# 6  6   Charizard   Fire  Flying  78     84      78     109      85   100
#
#   Generation Legendary
# 4          1     False
# 5          1     False
# 6          1     False

# %%
for index, row in df.iterrows():
    print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.describe()
# Out:
#           #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# count   801        801    801     415  801     801      801      801      801
# unique  722        801     18      18   95     112      104      106       93
# top     479  Bulbasaur  Water  Flying   60     100       70       60       80
# freq      6          1    112      97   67      40       54       51       52
#
#         Speed  Generation Legendary
# count     801         801       801
# unique    109           7         3
# top        50           1     False
# freq       46         166       735

# %%
df.sort_values("Name", ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP Attack Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108    100     121
# 695  634                 Zweilous     Dark  Dragon   72     85      70
# 46    41                    Zubat   Poison  Flying   40     45      35
# 631  570                    Zorua     Dark     NaN   40     65      40
# 632  571                  Zoroark     Dark     NaN   60    105      60
# ..   ...                      ...      ...     ...  ...    ...     ...
# 393  359          AbsolMega Absol     Dark     NaN   65    150      60
# 392  359                    Absol     Dark     NaN   65    130      60
# 68    63                     Abra  Psychic     NaN   25     20      15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90    132     105
# 510  460                Abomasnow    Grass     Ice   90     92      75
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 794      81      95    95          6      True
# ...

# %%
df.sort_values(["HP","Attack"] ,ascending=False)
# Out:
#            #       Name   Type 1 Type 2    HP Attack Defense Sp. Atk Sp. Def  \
# Type 1  Fire       Fire     Fire   Fire  Fire   Fire    Fire    Fire    Fire
# 261      242    Blissey   Normal    NaN   255     10      10      75     135
# 121      113    Chansey   Normal    NaN   250      5       5      35     105
# 217      202  Wobbuffet  Psychic    NaN   190     33      58      33      58
# 351      321    Wailord    Water    NaN   170     90      45      90      45
# ...      ...        ...      ...    ...   ...    ...     ...     ...     ...
# 381      349     Feebas    Water    NaN    20     15      20      10      55
# 139      129   Magikarp    Water    NaN    20     10      55      15      20
# 230      213    Shuckle      Bug   Rock    20     10     230      10     230
# 55        50    Diglett   Ground    NaN    10     55      25      35      45
# 316      292   Shedinja      Bug  Ghost     1     90      45      30      30
#
#        Speed Generation Legendary
# ...

# %%
df
# Out:
#            #                   Name   Type 1  Type 2    HP Attack Defense  \
# 0          1              Bulbasaur    Grass  Poison    45     49      49
# 1          2                Ivysaur    Grass  Poison    60     62      63
# 2          3               Venusaur    Grass  Poison    80     82      83
# 3          3  VenusaurMega Venusaur    Grass  Poison    80    100     123
# 4          4             Charmander     Fire     NaN    39     52      43
# ...      ...                    ...      ...     ...   ...    ...     ...
# 796      719    DiancieMega Diancie     Rock   Fairy    50    160     110
# 797      720    HoopaHoopa Confined  Psychic   Ghost    80    110      60
# 798      720     HoopaHoopa Unbound  Psychic    Dark    80    160      60
# 799      721              Volcanion     Fire   Water    80    110     120
# Type 1  Fire                   Fire     Fire    Fire  Fire   Fire    Fire
#
#        Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
df.drop("Type 1",inplace=True) #deleting the strange row

# %%
df["Total"] = df["HP"] + df["Attack"]+df["Defense"]+ df["Sp. Atk"] + df["Sp. Def"] + df["Speed"]

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP Attack Defense Sp. Atk Sp. Def Speed  \
# 0  1  Bulbasaur  Grass  Poison  45     49      49      65      65    45
# 1  2    Ivysaur  Grass  Poison  60     62      63      80      80    60
# 2  3   Venusaur  Grass  Poison  80     82      83     100     100    80
#
#   Generation Legendary Total
# 0          1     False   318
# 1          1     False   405
# 2          1     False   525

# %%
df.drop(columns=["Total"]) # temporary deletion, inplace= True makes it permenant change
# Out:
#            #                   Name   Type 1  Type 2    HP Attack Defense  \
# 0          1              Bulbasaur    Grass  Poison    45     49      49
# 1          2                Ivysaur    Grass  Poison    60     62      63
# 2          3               Venusaur    Grass  Poison    80     82      83
# 3          3  VenusaurMega Venusaur    Grass  Poison    80    100     123
# 4          4             Charmander     Fire     NaN    39     52      43
# ...      ...                    ...      ...     ...   ...    ...     ...
# 796      719    DiancieMega Diancie     Rock   Fairy    50    160     110
# 797      720    HoopaHoopa Confined  Psychic   Ghost    80    110      60
# 798      720     HoopaHoopa Unbound  Psychic    Dark    80    160      60
# 799      721              Volcanion     Fire   Water    80    110     120
# Type 1  Fire                   Fire     Fire    Fire  Fire   Fire    Fire
#
#        Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
df.drop(columns=["Total"], inplace=True)

# %%
df["Total"] =df.iloc[:,4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df["Total"] = df["Total"].astype("i") # returning float to integer

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP Attack Defense Sp. Atk Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45     49      49      65      65
# 1  2                Ivysaur  Grass  Poison  60     62      63      80      80
# 2  3               Venusaur  Grass  Poison  80     82      83     100     100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80    100     123     122     120
# 4  4             Charmander   Fire     NaN  39     52      43      60      50
#
#   Speed Generation Legendary  Total
# 0    45          1     False    318
# 1    60          1     False    405
# 2    80          1     False    525
# 3    80          1     False    625
# 4    65          1     False    309

# %%
#changing the order of the columns

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
df[cols[::-1]] # a reverse ordering of columns
# Out:
#      Total Legendary Generation Speed Sp. Def Sp. Atk Defense Attack  HP  \
# 0      318     False          1    45      65      65      49     49  45
# 1      405     False          1    60      80      80      63     62  60
# 2      525     False          1    80     100     100      83     82  80
# 3      625     False          1    80     120     122     123    100  80
# 4      309     False          1    65      50      60      43     52  39
# ..     ...       ...        ...   ...     ...     ...     ...    ...  ..
# 795    600      True          6    50     150     100     150    100  50
# 796    700      True          6   110     110     160     110    160  50
# 797    600      True          6    70     130     150      60    110  80
# 798    680      True          6    80     130     170      60    160  80
# 799    600      True          6    70      90     130     120    110  80
#
#      Type 2   Type 1                   Name    #
# ...

# %%
df.iloc[:,::-1] # also another method of reverse ordering of columns
# Out:
#     Legendary Generation Speed Sp. Def Sp. Atk Defense Attack  HP  Total  \
# 0       False          1    45      65      65      49     49  45    318
# 1       False          1    60      80      80      63     62  60    405
# 2       False          1    80     100     100      83     82  80    525
# 3       False          1    80     120     122     123    100  80    625
# 4       False          1    65      50      60      43     52  39    309
# ..        ...        ...   ...     ...     ...     ...    ...  ..    ...
# 795      True          6    50     150     100     150    100  50    600
# 796      True          6   110     110     160     110    160  50    700
# 797      True          6    70     130     150      60    110  80    600
# 798      True          6    80     130     170      60    160  80    680
# 799      True          6    70      90     130     120    110  80    600
#
#      Type 2   Type 1                   Name    #
# ...

# %% [markdown]
# ### Filtering Data

# %%
df[(df["Type 1"] == "Grass")  & (df["Type 2"] == "Poison")]
# Out:
#        #                   Name Type 1  Type 2  Total   HP Attack Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45     49      49
# 1      2                Ivysaur  Grass  Poison    405   60     62      63
# 2      3               Venusaur  Grass  Poison    525   80     82      83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80    100     123
# 48    43                 Oddish  Grass  Poison    320   45     50      55
# 49    44                  Gloom  Grass  Poison    395   60     65      70
# 50    45              Vileplume  Grass  Poison    490   75     80      85
# 75    69             Bellsprout  Grass  Poison    300   50     75      35
# 76    70             Weepinbell  Grass  Poison    390   65     90      50
# 77    71             Victreebel  Grass  Poison    490   80    105      65
# 344  315                Roselia  Grass  Poison    400   50     60      45
# 451  406                  Budew  Grass  Poison    280   40     30      35
# ...

# %%
a = df[(df["Attack"] > 100) & (df["Speed"] > 120) & (df["Defense"] > 85)]

# %%
a.reset_index(drop=True)
# Out:
#    index    #                     Name   Type 1    Type 2  Total   HP Attack  \
# 0    162  150                   Mewtwo  Psychic       NaN    680  106    110
# 1    163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106    190
# 2    476  428      LopunnyMega Lopunny   Normal  Fighting    580   65    136
# 3    716  648  MeloettaPirouette Forme   Normal  Fighting    600  100    128
#
#   Defense Sp. Atk Sp. Def Speed Generation Legendary
# 0      90     154      90   130          1      True
# 1     100     154     100   130          1      True
# 2      94      54      96   135          4     False
# 3      90      77      77   128          5     False

# %%
a
# Out:
#    index    #                     Name   Type 1    Type 2  Total   HP Attack  \
# 0    162  150                   Mewtwo  Psychic       NaN    680  106    110
# 1    163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106    190
# 2    476  428      LopunnyMega Lopunny   Normal  Fighting    580   65    136
# 3    716  648  MeloettaPirouette Forme   Normal  Fighting    600  100    128
#
#   Defense Sp. Atk Sp. Def Speed Generation Legendary
# 0      90     154      90   130          1      True
# 1     100     154     100   130          1      True
# 2      94      54      96   135          4     False
# 3      90      77      77   128          5     False

# %%
df[df["Type 1"].str.contains("Grass|Fire|Normal", regex=True)]
# Out:
#        #                   Name  Type 1  Type 2  Total   HP Attack Defense  \
# 0      1              Bulbasaur   Grass  Poison    318   45     49      49
# 1      2                Ivysaur   Grass  Poison    405   60     62      63
# 2      3               Venusaur   Grass  Poison    525   80     82      83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625   80    100     123
# 4      4             Charmander    Fire     NaN    309   39     52      43
# ..   ...                    ...     ...     ...    ...  ...    ...     ...
# 736  668                 Pyroar    Fire  Normal    507   86     68      72
# 740  672                 Skiddo   Grass     NaN    350   66     65      48
# 741  673                 Gogoat   Grass     NaN    531  123    100      62
# 744  676                Furfrou  Normal     NaN    472   75     80      60
# 799  721              Volcanion    Fire   Water    600   80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
import re

df[df["Name"].str.contains("^pid", regex=True, flags=re.I )]
# Out:
#        #                 Name  Type 1  Type 2  Total  HP Attack Defense  \
# 20    16               Pidgey  Normal  Flying    251  40     45      40
# 21    17            Pidgeotto  Normal  Flying    349  63     60      55
# 22    18              Pidgeot  Normal  Flying    479  83     80      75
# 23    18  PidgeotMega Pidgeot  Normal  Flying    579  83     80      80
# 578  519               Pidove  Normal  Flying    264  50     55      50
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 20       35      35    56          1     False
# 21       50      50    71          1     False
# 22       70      70   101          1     False
# 23      135      80   121          1     False
# 578      36      30    43          5     False

# %%
df[df["Name"].str.endswith("ve")]
# Out:
#        #    Name  Type 1  Type 2  Total  HP Attack Defense Sp. Atk Sp. Def  \
# 578  519  Pidove  Normal  Flying    264  50     55      50      36      30
#
#     Speed Generation Legendary
# 578    43          5     False

# %%
k  = df.replace("Fire" , "Flamer")

# %%
k
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   Flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   Flamer   Water    600  80     110      120
#
# ...

# %%
l = df.Name.replace("Venusaur", "Iris")

# %%
l
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                       Iris
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.loc[df["Type 1"] == "Fire", "Legendary"] =True
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45     49      49
# 1      2                Ivysaur    Grass  Poison    405  60     62      63
# 2      3               Venusaur    Grass  Poison    525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80    100     123
# 4      4             Charmander     Fire     NaN    309  39     52      43
# ..   ...                    ...      ...     ...    ...  ..    ...     ...
# 795  719                Diancie     Rock   Fairy    600  50    100     150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50    160     110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80    110      60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80    160      60
# 799  721              Volcanion     Fire   Water    600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
df.loc[df["Total"] > 500, ["Generation", "Legendary"]] = ["Test 1", "Test 2"]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45     49      49
# 1      2                Ivysaur    Grass  Poison    405  60     62      63
# 2      3               Venusaur    Grass  Poison    525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80    100     123
# 4      4             Charmander     Fire     NaN    309  39     52      43
# ..   ...                    ...      ...     ...    ...  ..    ...     ...
# 795  719                Diancie     Rock   Fairy    600  50    100     150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50    160     110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80    110      60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80    160      60
# 799  721              Volcanion     Fire   Water    600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %% [markdown]
# ### Aggregate Statistics (Groupby)

# %%
df.groupby("Type 1").mean()
# Out:
# C:\Users\90545\AppData\Local\Temp\ipykernel_7656\2155611706.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Type 1").mean()
#                Total
# Type 1
# Bug       378.927536
# Dark      445.741935
# Dragon    550.531250
# Electric  443.409091
# Fairy     413.176471
# Fighting  416.444444
# Fire      458.076923
# Flying    485.000000
# Ghost     439.562500
# Grass     421.142857
# Ground    437.500000
# Ice       433.458333
# Normal    401.683673
# Poison    399.142857
# Psychic   475.947368
# Rock      453.750000
# Steel     487.703704
# Water     430.455357

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  \
# 0      1              Bulbasaur    Grass  Poison           1      False
# 1      2                Ivysaur    Grass  Poison           1      False
# 2      3               Venusaur    Grass  Poison           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False
# 4      4             Charmander     Fire     NaN           1      False
# ..   ...                    ...      ...     ...         ...        ...
# 795  719                Diancie     Rock   Fairy           6       True
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True
# 799  721              Volcanion     Fire   Water           6       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
#changing the order of the columns again :)
cols = list(df.columns)
df = df[cols[0:4] + cols[6:] + cols[4:6]]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.groupby("Name")[["Total"]].mean()
# Out:
#                          Total
# Name
# Abomasnow                494.0
# AbomasnowMega Abomasnow  594.0
# Abra                     310.0
# Absol                    465.0
# AbsolMega Absol          565.0
# ...                        ...
# Zoroark                  510.0
# Zorua                    330.0
# Zubat                    245.0
# Zweilous                 420.0
# Zygarde50% Forme         600.0
#
# [800 rows x 1 columns]

# %%
df.Attack.transpose().mean()
# Out:
# 79.00125

# %%
df.Defense.apply("mean")
# Out:
# 73.8425

# %%
df.Defense.apply(np.mean)
# Out:
# 0       49.0
# 1       63.0
# 2       83.0
# 3      123.0
# 4       43.0
#        ...
# 795    150.0
# 796    110.0
# 797     60.0
# 798     60.0
# 799    120.0
# Name: Defense, Length: 800, dtype: float64

# %%
df.groupby(["Name"]).mean() # includes every numerical values
# Out:
# C:\Users\90545\AppData\Local\Temp\ipykernel_11180\1178643031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["Name"]).mean()
#                              #  Total     HP  Attack  Defense  Sp. Atk  \
# Name
# Abomasnow                460.0  494.0   90.0    92.0     75.0     92.0
# AbomasnowMega Abomasnow  460.0  594.0   90.0   132.0    105.0    132.0
# Abra                      63.0  310.0   25.0    20.0     15.0    105.0
# Absol                    359.0  465.0   65.0   130.0     60.0     75.0
# AbsolMega Absol          359.0  565.0   65.0   150.0     60.0    115.0
# ...                        ...    ...    ...     ...      ...      ...
# Zoroark                  571.0  510.0   60.0   105.0     60.0    120.0
# ...

# %%
df.groupby(["Type 1"]).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df.groupby("Type 1")["Type 1"].count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Type 1, dtype: int64
