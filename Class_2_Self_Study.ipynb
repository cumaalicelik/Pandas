# %%
import numpy as np
import pandas as pd

# %%
data = {"name": ["james", "felix", "erica", "kamal"], "height-cm": [1.70, 1.55, 1.60, 1.90], "weight-kgs": [70,55,60,80]}
data
# Out:
# {'name': ['james', 'felix', 'erica', 'kamal'],
#  'height-cm': [1.7, 1.55, 1.6, 1.9],
#  'weight-kgs': [70, 55, 60, 80]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     name  height-cm  weight-kgs
# 0  james       1.70          70
# 1  felix       1.55          55
# 2  erica       1.60          60
# 3  kamal       1.90          80

# %%
df = pd.DataFrame(data,index="A B C D".split())
df
# Out:
#     name  height-cm  weight-kgs
# A  james       1.70          70
# B  felix       1.55          55
# C  erica       1.60          60
# D  kamal       1.90          80

# %%
df.name
# Out:
# A    james
# B    felix
# C    erica
# D    kamal
# Name: name, dtype: object

# %%
df["name"]
# Out:
# A    james
# B    felix
# C    erica
# D    kamal
# Name: name, dtype: object

# %%
df[["name"]] # we can see the indexes and columns
# Out:
#     name
# A  james
# B  felix
# C  erica
# D  kamal

# %%
df[["height-cm"]]
# Out:
#    height-cm
# A       1.70
# B       1.55
# C       1.60
# D       1.90

# %%
df[["weight-kgs", "name"]]
# Out:
#    weight-kgs   name
# A          70  james
# B          55  felix
# C          60  erica
# D          80  kamal

# %%
df["A":"B"]
# Out:
#     name  height-cm  weight-kgs
# A  james       1.70          70
# B  felix       1.55          55

# %%
df[:2]
# Out:
#     name  height-cm  weight-kgs
# A  james       1.70          70
# B  felix       1.55          55

# %%
df[:2]["name"]
# Out:
# A    james
# B    felix
# Name: name, dtype: object

# %%
df["name"]["A"]
# Out:
# 'james'

# %%
df[2:][["name"]]
# Out:
#     name
# C  erica
# D  kamal

# %%
df["C":"C"][["weight-kgs"]]
# Out:
#    weight-kgs
# C          60

# %%
df["C":"D"][["name"]]
# Out:
#     name
# C  erica
# D  kamal

# %%
df[::] #everythig included
# Out:
#     name  height-cm  weight-kgs
# A  james       1.70          70
# B  felix       1.55          55
# C  erica       1.60          60
# D  kamal       1.90          80

# %%
df["C":"C"][["name", "weight-kgs"]]
# Out:
#     name  weight-kgs
# C  erica          60

# %%
df["A":"A"][["name","weight-kgs"]]
# Out:
#     name  weight-kgs
# A  james          70

# %%
df["name"]["B"]
# Out:
# 'felix'

# %%
df["B":"B"][["name"]]
# Out:
#     name
# B  felix

# %%
#new column creating

# %%
df
# Out:
#      name height-cm weight-kgs   age  number
# A   james       1.7         70  41.0       1
# B   felix      1.55         55  35.0       2
# C   erica       1.6         60  37.0       3
# D   kamal       1.9         80  42.0       4
# E  robert      1.85         77    32       5
# F   sarah      1.72         65    29       6

# %%
df["age"] = (df["weight-kgs"] // df["height-cm"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
# --> 242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for //: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.loc["E"]= ["robert", "1.85","77", "32"]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 df.loc["E"]= ["robert", "1.85","77", "32"]
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1795, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1792 # align and set the values
#    1793 if take_split_path:
#    1794     # We have to operate column-wise
# -> 1795     self._setitem_with_indexer_split_path(indexer, value, name)
#    1796 else:
#    1797     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df["number"]= np.arange(1,6)
df
# Out:
#      name height-cm weight-kgs   age  number
# A   james       1.7         70  41.0       1
# B   felix      1.55         55  35.0       2
# C   erica       1.6         60  37.0       3
# D   kamal       1.9         80  42.0       4
# E  robert      1.85         77    32       5

# %%
df.loc["F"] = ["sarah", 1.72, 65, 29, 6]
df
# Out:
#      name height-cm weight-kgs   age  number
# A   james       1.7         70  41.0       1
# B   felix      1.55         55  35.0       2
# C   erica       1.6         60  37.0       3
# D   kamal       1.9         80  42.0       4
# E  robert      1.85         77    32       5
# F   sarah      1.72         65    29       6

# %%
df["grade"] = df["age"] *2
df
# Out:
#      name height-cm weight-kgs   age  number grade
# A   james       1.7         70  41.0       1  82.0
# B   felix      1.55         55  35.0       2  70.0
# C   erica       1.6         60  37.0       3  74.0
# D   kamal       1.9         80  42.0       4  84.0
# E  robert      1.85         77    32       5  3232
# F   sarah      1.72         65    29       6    58

# %%
#removing columns & rows

# %%
df.drop("age", axis=1,) #temporary
# Out:
#      name height-cm weight-kgs  number grade
# A   james       1.7         70       1  82.0
# B   felix      1.55         55       2  70.0
# C   erica       1.6         60       3  74.0
# D   kamal       1.9         80       4  84.0
# E  robert      1.85         77       5  3232
# F   sarah      1.72         65       6    58

# %%
df
# Out:
#      name height-cm weight-kgs   age  number grade
# A   james       1.7         70  41.0       1  82.0
# B   felix      1.55         55  35.0       2  70.0
# C   erica       1.6         60  37.0       3  74.0
# D   kamal       1.9         80  42.0       4  84.0
# E  robert      1.85         77    32       5  3232
# F   sarah      1.72         65    29       6    58

# %%
df.drop("E", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 df.drop("E", inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#     name height-cm weight-kgs   age  number grade
# A  james       1.7         70  41.0       1  82.0
# B  felix      1.55         55  35.0       2  70.0
# C  erica       1.6         60  37.0       3  74.0
# D  kamal       1.9         80  42.0       4  84.0
# F  sarah      1.72         65    29       6    58

# %%
df.drop(["F"])
# Out:
#     name height-cm weight-kgs   age  number grade
# A  james       1.7         70  41.0       1  82.0
# B  felix      1.55         55  35.0       2  70.0
# C  erica       1.6         60  37.0       3  74.0
# D  kamal       1.9         80  42.0       4  84.0

# %%
df
# Out:
#     name height-cm weight-kgs   age  number grade
# A  james       1.7         70  41.0       1  82.0
# B  felix      1.55         55  35.0       2  70.0
# C  erica       1.6         60  37.0       3  74.0
# D  kamal       1.9         80  42.0       4  84.0
# F  sarah      1.72         65    29       6    58

# %%
df.drop(["B", "F"]).drop(["weight-kgs", "age"], axis=1) #column abd row together
# Out:
#     name height-cm  number grade
# A  james       1.7       1  82.0
# C  erica       1.6       3  74.0
# D  kamal       1.9       4  84.0

# %%
df.loc[["A"]]
# Out:
#     name height-cm weight-kgs   age  number grade
# A  james       1.7         70  41.0       1  82.0

# %%
df.loc[["A"]][["name","age"]]
# Out:
#     name   age
# A  james  41.0

# %%
data2 = np.arange(1,21).reshape(5,4)
df2 = pd.DataFrame(data2, columns=["col1", "col2", "col3", "col4"], index=range(1,6))
df2
# Out:
#    col1  col2  col3  col4
# 1     1     2     3     4
# 2     5     6     7     8
# 3     9    10    11    12
# 4    13    14    15    16
# 5    17    18    19    20

# %%
df2.loc[1] #index no 1
# Out:
# col1    1
# col2    2
# col3    3
# col4    4
# Name: 1, dtype: int32

# %%
df2.loc[3]
# Out:
# col1     9
# col2    10
# col3    11
# col4    12
# Name: 3, dtype: int32

# %%
df2.loc[1:3]
# Out:
#    col1  col2  col3  col4
# 1     1     2     3     4
# 2     5     6     7     8
# 3     9    10    11    12

# %%
df2[:3]
# Out:
#    col1  col2  col3  col4
# 1     1     2     3     4
# 2     5     6     7     8
# 3     9    10    11    12

# %%
df2.iloc[1:3] #default index
# Out:
#    col1  col2  col3  col4
# 2     5     6     7     8
# 3     9    10    11    12

# %%
df2.index = [10,11,12,13,14]
df2
# Out:
#     col1  col2  col3  col4
# 10     1     2     3     4
# 11     5     6     7     8
# 12     9    10    11    12
# 13    13    14    15    16
# 14    17    18    19    20

# %%
df2.index ="a b c d e".split()

df2
# Out:
#    col1  col2  col3  col4
# a     1     2     3     4
# b     5     6     7     8
# c     9    10    11    12
# d    13    14    15    16
# e    17    18    19    20

# %%
df2.columns= [1,2,3,4]
df2
# Out:
#     1   2   3   4
# a   1   2   3   4
# b   5   6   7   8
# c   9  10  11  12
# d  13  14  15  16
# e  17  18  19  20

# %%
df2.columns = "x y z t".split()

df2
# Out:
#     x   y   z   t
# a   1   2   3   4
# b   5   6   7   8
# c   9  10  11  12
# d  13  14  15  16
# e  17  18  19  20

# %%
df2.loc["b":"c"][["x","y"]]
# Out:
#    x   y
# b  5   6
# c  9  10

# %%
df2.iloc[2][0]
# Out:
# 9

# %%
df2.loc[:,["z"]]
# Out:
#     z
# a   3
# b   7
# c  11
# d  15
# e  19

# %%
df2.loc["c":][["y","x"]]
# Out:
#     y   x
# c  10   9
# d  14  13
# e  18  17

# %%
#condiional selection

# %%
df3 = pd.DataFrame(np.random.randn(5,4), index="a b c d e".split(), columns ="A B C D".split())
df3
# Out:
#           A         B         C         D
# a  1.304451 -0.025138 -0.012436 -0.711831
# b  0.110155  2.466811 -1.070917 -0.636294
# c -0.093201  1.574643 -0.692228  0.462710
# d  0.922041  1.274385 -0.299688 -0.677139
# e  0.615957  0.820920 -0.197718  0.576905

# %%
d = np.random.randint(0,100,20)
d.reshape(5,4)
# Out:
# array([[25,  7, 69, 10],
#        [59, 40, 80, 53],
#        [28, 85, 26, 77],
#        [93, 99, 63, 55],
#        [63,  3, 67, 93]])

# %%
f= pd.DataFrame(d.reshape(5,4),index="a b c d e".split(), columns="A B C D".split())
f
# Out:
#     A   B   C   D
# a  25   7  69  10
# b  59  40  80  53
# c  28  85  26  77
# d  93  99  63  55
# e  63   3  67  93

# %%
f > 50
# Out:
#        A      B      C      D
# a  False  False   True  False
# b   True  False   True   True
# c  False   True  False   True
# d   True   True   True   True
# e   True  False   True   True

# %%
f[f>50]
# Out:
#       A     B     C     D
# a   NaN   NaN  69.0   NaN
# b  59.0   NaN  80.0  53.0
# c   NaN  85.0   NaN  77.0
# d  93.0  99.0  63.0  55.0
# e  63.0   NaN  67.0  93.0

# %%
f[f["A"]>50][["C"]]
# Out:
#     C
# b  80
# d  63
# e  67

# %%
f[f>50][["A","B"]]
# Out:
#       A     B
# a   NaN   NaN
# b  59.0   NaN
# c   NaN  85.0
# d  93.0  99.0
# e  63.0   NaN

# %%
f[(f["B"]>50) & (f["C"]<50)]
# Out:
#     A   B   C   D
# c  28  85  26  77

# %%
f[f["c":"c"]>0]
# Out:
#       A     B     C     D
# a   NaN   NaN   NaN   NaN
# b   NaN   NaN   NaN   NaN
# c  28.0  85.0  26.0  77.0
# d   NaN   NaN   NaN   NaN
# e   NaN   NaN   NaN   NaN

# %%
f[f["d":"d"]>25][["C"]]
# Out:
#       C
# a   NaN
# b   NaN
# c   NaN
# d  63.0
# e   NaN

# %%
f[["A","B"]][(f["A"] > 20) & (f["B"] < 20)]
# Out:
#     A  B
# a  25  7
# e  63  3

# %%
f[["A","B"]][(f["A"] > 80) | (f["B"] < 10)]
# Out:
#     A   B
# a  25   7
# d  93  99
# e  63   3

# %%
# set_index() & reset_index()

# %%
f
# Out:
#     A   B   C   D
# a  25   7  69  10
# b  59  40  80  53
# c  28  85  26  77
# d  93  99  63  55
# e  63   3  67  93

# %%
f.reset_index()
# Out:
#   index   A   B   C   D
# 0     a  25   7  69  10
# 1     b  59  40  80  53
# 2     c  28  85  26  77
# 3     d  93  99  63  55
# 4     e  63   3  67  93

# %%
f.reset_index(drop=True)
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 2  28  85  26  77
# 3  93  99  63  55
# 4  63   3  67  93

# %%
f.reset_index(drop=True,inplace=True)

f
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 2  28  85  26  77
# 3  93  99  63  55
# 4  63   3  67  93

# %%
f
# Out:
#    index   B   A   C   D
# 0      0   7  25  69  10
# 1      1  40  59  80  53
# 2      2  85  28  26  77
# 3      3  99  93  63  55
# 4      4   3  63  67  93

# %%
f.reset_index(drop=True,inplace=True)
f
# Out:
#    index   B   A   C   D
# 0      0   7  25  69  10
# 1      1  40  59  80  53
# 2      2  85  28  26  77
# 3      3  99  93  63  55
# 4      4   3  63  67  93

# %%
f = f[["A", "B", "C","D"]]
f
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 2  28  85  26  77
# 3  93  99  63  55
# 4  63   3  67  93

# %%
f.drop([2],axis=0, inplace=True)
# Out:
# C:\Users\90545\AppData\Local\Temp\ipykernel_14728\1834069758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f.drop([2],axis=0, inplace=True)

# %%
f
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 3  93  99  63  55
# 4  63   3  67  93

# %%
f.drop([3], axis=0)
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 4  63   3  67  93

# %%
f
# Out:
#     A   B   C   D
# 0  25   7  69  10
# 1  59  40  80  53
# 3  93  99  63  55
# 4  63   3  67  93

# %%
f.set_index("C", drop=False)
# Out:
#      A   B   C   D
# C
# 69  25   7  69  10
# 80  59  40  80  53
# 63  93  99  63  55
# 67  63   3  67  93

# %%
# Some Useful Methods with Titanic Dataset

# %%
#pip install seaborn
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df4 = sns.load_dataset("car_crashes")
df4
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df4.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df4.sample(10)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 29   11.6     4.060    3.480          10.092        9.628       746.54
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 20   12.5     4.250    4.000           8.875       12.375      1048.78
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 25   16.1     6.923    5.474          14.812       13.524       790.32
#
#     ins_losses abbrev
# 3       142.39     AR
# 14      108.92     IN
# 8       136.05     DC
# 49      106.62     WI
# 36      178.86     OK
# 29      120.21     NH
# 43      156.83     TX
# ...

# %%
df4.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
df4.describe(include=object).T
# Out:
#        count unique top freq
# abbrev    51     51  AL    1

# %%
df4[df4.alcohol >=7]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
#
#     ins_losses abbrev
# 11      120.92     HI
# 26       85.15     MT
# 34      109.72     ND
# 40      116.29     SC
# 43      156.83     TX

# %%
df4.describe(include="all").T
# Out:
#                count unique  top freq        mean         std     min  \
# total           51.0    NaN  NaN  NaN   15.790196    4.122002     5.9
# speeding        51.0    NaN  NaN  NaN    4.998196    2.017747   1.792
# alcohol         51.0    NaN  NaN  NaN    4.886784    1.729133   1.593
# not_distracted  51.0    NaN  NaN  NaN   13.573176    4.508977    1.76
# no_previous     51.0    NaN  NaN  NaN   14.004882    3.764672     5.9
# ins_premium     51.0    NaN  NaN  NaN  886.957647  178.296285  641.96
# ins_losses      51.0    NaN  NaN  NaN  134.493137   24.835922   82.75
# abbrev            51     51   AL    1         NaN         NaN     NaN
#
#                     25%     50%       75%      max
# total             12.75    15.6      18.5     23.9
# speeding         3.7665   4.608     6.439     9.45
# alcohol           3.894   4.554     5.604   10.038
# not_distracted   10.478  13.857     16.14   23.661
# no_previous      11.348  13.775    16.755    21.28
# ...

# %%
df4.corr()
# Out:
# C:\Users\90545\AppData\Local\Temp\ipykernel_14728\3006967730.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...
